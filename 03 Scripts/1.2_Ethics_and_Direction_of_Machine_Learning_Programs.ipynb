# %% [markdown]
# # Checking and Scaling Dataframe

# %% [markdown]
# # Table of Contents
#
# 1. Import Data & Libraries
# 2. Check for Missing Values
# 3. Scaling Data
# 4. Export Dataset

# %% [markdown]
# # Import  Data & Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.preprocessing import StandardScaler

# %%
# Create a path for importing
path = r'C:\Users\shrav\_Data_Analysis_CF\ML_ClimateWins_Project'

# %%
df = pd.read_csv(os.path.join(path,'02 Data', 'Original_Data','Dataset-weather-prediction-dataset-processed.csv'), index_col=False)

# %%
df.head()
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0  19600101      1                  7               2.1            0.85
# 1  19600102      1                  6               2.1            0.84
# 2  19600103      1                  8               2.1            0.90
# 3  19600104      1                  3               2.1            0.92
# 4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# 0                 0             0.7  ...                     5
# ...

# %%
#View data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22950 entries, 0 to 22949
# Columns: 170 entries, DATE to VALENTIA_temp_max
# dtypes: float64(145), int64(25)
# memory usage: 29.8 MB

# %%
df.shape
# Out:
# (22950, 170)

# %%
df.reset_index(inplace=True)
df.rename(columns={'index':'id'}, inplace=True)
df.head()
# Out:
#    id      DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0   0  19600101      1                  7               2.1            0.85
# 1   1  19600102      1                  6               2.1            0.84
# 2   2  19600103      1                  8               2.1            0.90
# 3   3  19600104      1                  3               2.1            0.92
# 4   4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  ...  VALENTIA_cloud_cover  VALENTIA_humidity  \
# ...

# %% [markdown]
# # 2. Check for missing values

# %%
df.isnull().sum()
# Out:
# id                     0
# DATE                   0
# MONTH                  0
# BASEL_cloud_cover      0
# BASEL_wind_speed       0
#                       ..
# VALENTIA_snow_depth    0
# VALENTIA_sunshine      0
# VALENTIA_temp_mean     0
# VALENTIA_temp_min      0
# VALENTIA_temp_max      0
# Length: 171, dtype: int64

# %%
# Drop the NaN values

df.dropna(inplace=True)

# %%
df.shape
# Out:
# (22950, 171)

# %%
# Check for duplicates

df_dup = df[df.duplicated()]

# %%
df_dup
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# #### No missing and duplicate values were found in this dataframe

# %%
# Subset new dataframe, dropping time variable 'DATE', 'MONTH'
cols_to_drop = ['DATE', 'MONTH']

# Drop the specified columns
df_sub = df.drop(columns=cols_to_drop)

# Display subset df
df_sub
# Out:
#           id  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0          0                  7               2.1            0.85
# 1          1                  6               2.1            0.84
# 2          2                  8               2.1            0.90
# 3          3                  3               2.1            0.92
# 4          4                  6               2.1            0.95
# ...      ...                ...               ...             ...
# 22945  22945                  1               2.1            0.79
# 22946  22946                  6               2.1            0.77
# 22947  22947                  4               2.1            0.76
# 22948  22948                  5               2.1            0.80
# 22949  22949                  5               2.1            0.84
#
#        BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0              1.0180                    0.32                 0.09
# ...

# %% [markdown]
# # 3. Scaling Data

# %%
#create scaler object using StandardScaler from sklearn.preprocessing
#StandardScaler assumes data is normally distributed and scales with a distribution
#around 0 and standard deviation of 1. Scaling happens independently with each variable.

scaler = StandardScaler()

# %%
#Create new df with scaled data
df_scaled = pd.DataFrame(scaler.fit_transform(df_sub), columns=df_sub.columns)
df_scaled.head()
# Out:
#          id  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0 -1.731975           0.660514          -0.02793        0.826097
# 1 -1.731824           0.244897          -0.02793        0.735760
# 2 -1.731673           1.076130          -0.02793        1.277781
# 3 -1.731523          -1.001953          -0.02793        1.458455
# 4 -1.731372           0.244897          -0.02793        1.729466
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0       -0.001949               -1.101066            -0.265148
# 1       -0.001949               -1.058108             1.658760
# 2       -0.001949               -1.251420             0.155707
# 3       -0.001949               -0.821838            -0.445514
# 4       -0.001949               -0.746661            -0.164944
#
#    BASEL_snow_depth  BASEL_sunshine  BASEL_temp_mean  ...  \
# 0         -0.179228       -0.902918        -0.528623  ...
# 1         -0.179228       -0.810126        -0.582946  ...
# ...

# %%
# Compare the original vs. scaled data

df.head()
# Out:
#    id      DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0   0  19600101      1                  7               2.1            0.85
# 1   1  19600102      1                  6               2.1            0.84
# 2   2  19600103      1                  8               2.1            0.90
# 3   3  19600104      1                  3               2.1            0.92
# 4   4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  ...  VALENTIA_cloud_cover  VALENTIA_humidity  \
# ...

# %%
# Save the DataFrame to pickle files
df_scaled.to_pickle(os.path.join(path, '02 Data', 'Prepared_Data', 'weather_data_scaled.pkl'))
df_scaled.to_pickle(os.path.join(path, '02 Data', 'Supervised', 'weather_data_scaled.pkl'))
df_scaled.to_pickle(os.path.join(path, '02 Data', 'UnSupervised', 'weather_data_scaled.pkl'))
